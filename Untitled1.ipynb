# %%
#!/usr/bin/env python
# coding: utf-8

import os
import pandas as pd
import geopandas as gpd

# -------------------- Config --------------------
INPUT_CSV_NEWSET = "/explore/nobackup/people/spotter5/new_combustion/2025-08-08_LC_FISL_Original_combustionModelPredictors.csv"
OLD_PREDICTORS_CSV = "/explore/nobackup/people/spotter5/new_combustion/all_predictors.csv"
OUT_DIR = "/explore/nobackup/people/spotter5/new_combustion"
os.makedirs(OUT_DIR, exist_ok=True)

# Targets: keep a row if ANY of these has a non-NA observation
TARGETS = ['below.ground.carbon.combusted', 'above.carbon.combusted', 'burn.depth']

# -------------------- Load --------------------
df = pd.read_csv(INPUT_CSV_NEWSET)
old_ids_df = pd.read_csv(OLD_PREDICTORS_CSV)

# -------------------- Validate basic columns --------------------
if 'id' not in df.columns:
    raise SystemExit("❌ 'id' column is required in the input CSV.")

# choose latitude/longitude columns (fallback to lat/lon if needed)
lon_col = 'longitude' if 'longitude' in df.columns else ('lon' if 'lon' in df.columns else None)
lat_col = 'latitude'  if 'latitude'  in df.columns else ('lat' if 'lat' in df.columns else None)
if lon_col is None or lat_col is None:
    raise SystemExit("❌ Could not find longitude/latitude columns (tried: longitude/latitude, lon/lat).")

# -------------------- Filter to rows with at least one target observation --------------------
present_targets = [t for t in TARGETS if t in df.columns]
if not present_targets:
    raise SystemExit("❌ None of the target columns were found in the input CSV.")

mask_any_target = df[present_targets].notna().any(axis=1)
df_obs = df.loc[mask_any_target].copy()

# also require valid coordinates
df_obs = df_obs.dropna(subset=[lon_col, lat_col])

# -------------------- Split into NEW vs OLD by id --------------------
old_ids = set(old_ids_df['id'].unique())
df_old_rows = df_obs[df_obs['id'].isin(old_ids)].copy()
df_new_rows = df_obs[~df_obs['id'].isin(old_ids)].copy()

# -------------------- Deduplicate by site (id) so each site appears once --------------------
# Keep the first occurrence of each id (coordinates assumed stable per site)
df_old_sites = df_old_rows.sort_values('id').drop_duplicates(subset=['id'])
df_new_sites = df_new_rows.sort_values('id').drop_duplicates(subset=['id'])

# -------------------- Build GeoDataFrames --------------------
gdf_old = gpd.GeoDataFrame(
    df_old_sites,
    geometry=gpd.points_from_xy(df_old_sites[lon_col], df_old_sites[lat_col]),
    crs="EPSG:4326"
)
gdf_new = gpd.GeoDataFrame(
    df_new_sites,
    geometry=gpd.points_from_xy(df_new_sites[lon_col], df_new_sites[lat_col]),
    crs="EPSG:4326"
)

# -------------------- Save shapefiles --------------------
old_shp = os.path.join(OUT_DIR, "old.shp")
new_shp = os.path.join(OUT_DIR, "new.shp")
gdf_old.to_file(old_shp)
gdf_new.to_file(new_shp)

print(f"✅ Saved:\n  - {old_shp}  (n={len(gdf_old)})\n  - {new_shp}  (n={len(gdf_new)})")
# Out:
# /explore/nobackup/people/spotter5/temp_dir/ipykernel_3610889/1465216149.py:67: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_old.to_file(old_shp)
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'above.carbon.combusted' to 'above.carb'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'below.ground.carbon.combusted' to 'below.grou'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'project.name' to 'project.na'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Relative.humidity' to 'Relative.h'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Temperature' to 'Temperatur'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_Tmax_5_8' to 'CNA_Tmax_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_PPT_5_8' to 'CNA_PPT_5_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_Rad_5_8' to 'CNA_Rad_5_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_DD_0_5_8' to 'CNA_DD_0_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_DD5_5_8' to 'CNA_DD5_5_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_DD_18_5_8' to 'CNA_DD_18_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_DD18_sm' to 'CNA_DD18_s'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_NFFD_5_8' to 'CNA_NFFD_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_PAS_5_8' to 'CNA_PAS_5_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_Eref_5_8' to 'CNA_Eref_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_CMD_5_8' to 'CNA_CMD_5_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_Tave_5_8' to 'CNA_Tave_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_Tmin_5_8' to 'CNA_Tmin_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'project_name' to 'project_na'
#   ogr_write(
# /explore/nobackup/people/spotter5/temp_dir/ipykernel_3610889/1465216149.py:68: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_new.to_file(new_shp)
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'above.carbon.combusted' to 'above.carb'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'below.ground.carbon.combusted' to 'below.grou'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'project.name' to 'project.na'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Relative.humidity' to 'Relative.h'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Temperature' to 'Temperatur'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_Tmax_5_8' to 'CNA_Tmax_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_PPT_5_8' to 'CNA_PPT_5_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_Rad_5_8' to 'CNA_Rad_5_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_DD_0_5_8' to 'CNA_DD_0_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_DD5_5_8' to 'CNA_DD5_5_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_DD_18_5_8' to 'CNA_DD_18_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_DD18_sm' to 'CNA_DD18_s'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_NFFD_5_8' to 'CNA_NFFD_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_PAS_5_8' to 'CNA_PAS_5_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_Eref_5_8' to 'CNA_Eref_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_CMD_5_8' to 'CNA_CMD_5_'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_Tave_5_8' to 'CNA_Tave_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CNA_Tmin_5_8' to 'CNA_Tmin_5'
#   ogr_write(
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'project_name' to 'project_na'
#   ogr_write(
# ✅ Saved:
#   - /explore/nobackup/people/spotter5/new_combustion/old.shp  (n=964)
#   - /explore/nobackup/people/spotter5/new_combustion/new.shp  (n=866)
